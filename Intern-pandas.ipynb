# %%
#Basic Operations
import pandas as pd

# %%
weather_df=pd.read_csv('weather.csv')

# %%
weather_df.head()
# Out:
#    Unnamed: 0         day  temperature  windspeed  event
# 0           0  01-01-2022         32.0        6.0   Rain
# 1           1  01-04-2022          NaN        9.0  Sunny
# 2           2  01-05-2022         28.0        NaN   Snow
# 3           3  01-06-2022          NaN        7.0    NaN
# 4           4  01-07-2022         32.0        NaN   Rain

# %%
weather_df.isnull()
# Out:
#     Unnamed: 0    day  temperature  windspeed  event
# 0        False  False        False      False  False
# 1        False  False         True      False  False
# 2        False  False        False       True  False
# 3        False  False         True      False   True
# 4        False  False        False       True  False
# 5        False  False         True       True  False
# 6        False  False         True       True   True
# 7        False  False        False      False  False
# 8        False  False        False      False  False
# 9        False  False        False      False  False
# 10       False  False        False      False  False

# %%
weather_df.isnull().sum()

# %%
weather_df.dropna()
# Out:
#     Unnamed: 0         day  temperature  windspeed   event
# 0            0  01-01-2022         32.0        6.0    Rain
# 7            7  01-10-2022         34.0        8.0  Cloudy
# 8            8  01-10-2022         34.0        8.0  Cloudy
# 9            9  01-11-2022         40.0       12.0   Sunny
# 10          10  01-11-2022         40.0       12.0   Sunny

# %%
weather_df
# Out:
#     Unnamed: 0         day  temperature  windspeed   event
# 0            0  01-01-2022         32.0        6.0    Rain
# 1            1  01-04-2022          NaN        9.0   Sunny
# 2            2  01-05-2022         28.0        NaN    Snow
# 3            3  01-06-2022          NaN        7.0     NaN
# 4            4  01-07-2022         32.0        NaN    Rain
# 5            5  01-08-2022          NaN        NaN   Sunny
# 6            6  01-09-2022          NaN        NaN     NaN
# 7            7  01-10-2022         34.0        8.0  Cloudy
# 8            8  01-10-2022         34.0        8.0  Cloudy
# 9            9  01-11-2022         40.0       12.0   Sunny
# 10          10  01-11-2022         40.0       12.0   Sunny

# %%
weather_df['temperature'].max()
# Out:
# 40.0

# %%
weather_df[weather_df['temperature']>35]
# Out:
#     Unnamed: 0         day  temperature  windspeed  event
# 9            9  01-11-2022         40.0       12.0  Sunny
# 10          10  01-11-2022         40.0       12.0  Sunny

# %%
df1=weather_df.fillna(0)
df1

# %%
df2=weather_df
#df2[['temperature','windspeed']].fillna(df2[['temperature','windspeed']].mean(),inplace=True)
df2
# Out:
#     Unnamed: 0         day  temperature  windspeed   event
# 0            0  01-01-2022         32.0        6.0    Rain
# 1            1  01-04-2022          NaN        9.0   Sunny
# 2            2  01-05-2022         28.0        NaN    Snow
# 3            3  01-06-2022          NaN        7.0     NaN
# 4            4  01-07-2022         32.0        NaN    Rain
# 5            5  01-08-2022          NaN        NaN   Sunny
# 6            6  01-09-2022          NaN        NaN     NaN
# 7            7  01-10-2022         34.0        8.0  Cloudy
# 8            8  01-10-2022         34.0        8.0  Cloudy
# 9            9  01-11-2022         40.0       12.0   Sunny
# 10          10  01-11-2022         40.0       12.0   Sunny

# %%
df2['windspeed'].fillna(df2['windspeed'].mean(),inplace=True)

# %%
df2
df2.fillna({'event':'No records'},inplace=True)
df2

# %%
df2.drop(['Unnamed: 0'],axis=1,inplace=True) #df.drop(['A'], axis=1)

# %%
df2
# Out:
#            day  temperature  windspeed   event
# 0   01-01-2022         32.0        6.0    Rain
# 1   01-04-2022          NaN        9.0   Sunny
# 2   01-05-2022         28.0        NaN    Snow
# 3   01-06-2022          NaN        7.0     NaN
# 4   01-07-2022         32.0        NaN    Rain
# 5   01-08-2022          NaN        NaN   Sunny
# 6   01-09-2022          NaN        NaN     NaN
# 7   01-10-2022         34.0        8.0  Cloudy
# 8   01-10-2022         34.0        8.0  Cloudy
# 9   01-11-2022         40.0       12.0   Sunny
# 10  01-11-2022         40.0       12.0   Sunny

# %%
df2.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10     True
# dtype: bool

# %%
df2.drop_duplicates()
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2022         32.0        6.0    Rain
# 1  01-04-2022          NaN        9.0   Sunny
# 2  01-05-2022         28.0        NaN    Snow
# 3  01-06-2022          NaN        7.0     NaN
# 4  01-07-2022         32.0        NaN    Rain
# 5  01-08-2022          NaN        NaN   Sunny
# 6  01-09-2022          NaN        NaN     NaN
# 7  01-10-2022         34.0        8.0  Cloudy
# 9  01-11-2022         40.0       12.0   Sunny

# %%
import matplotlib.pyplot as plt

# %%
pd.value_counts(df2['event']).plot.bar()

# %%
df2.groupby(df2['event']).min()

# %% [markdown]
# **Analysis of Titanic Data**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic_df=pd.read_csv('titanic.csv')
print(titanic_df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Unnamed: 12
# 0      0         A/5 21171   7.2500   NaN        S          NaN
# 1      0          PC 17599  71.2833   C85        C          NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S          NaN
# ...

# %%
titanic_df.describe()

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Unnamed: 12  0 non-null      float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 90.6+ KB

# %%
titanic_df.isnull()

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Unnamed: 12    891
# dtype: int64

# %%
pd.value_counts(titanic_df['Survived']).plot.bar()
# Out:
# <Axes: >

# %%
titanic_df['Survived'].mean()

# %%
titanic_df['Survived'].groupby(titanic_df['Sex']).mean()

# %%
#titanic_df.groupby(['Sex']).mean()
titanic_df=pd.read_csv('titanic.csv')
titanic_df.groupby(['Sex']).mean()
# Out:
# <ipython-input-10-1f380302619e>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   titanic_df.groupby(['Sex']).mean()
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare  Unnamed: 12
# Sex
# female  44.479818          NaN
# male    25.523893          NaN

# %%
s1=pd.read_csv('titanic1.csv')
s1.groupby(['Pclass']).max()
# Out:
# <ipython-input-13-225844a87c0c>:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   s1.groupby(['Pclass']).max()
#         PassengerId  Survived                         Name   Sex   Age  SibSp  \
# Pclass
# 1               890         1     Young, Miss. Marie Grice  male  80.0      3
# 2               887         1    del Carlo, Mr. Sebastiano  male  70.0      3
# 3               891         1  van Melkebeke, Mr. Philemon  male  74.0      8
#
#         Parch      Ticket      Fare  Unnamed: 12
# Pclass
# 1           4   WE/P 5735  512.3292          NaN
# 2           3   W/C 14208   73.5000          NaN
# 3           6  W./C. 6609   69.5500          NaN
