# %% [markdown]
# **Series**
# A Series is a one-dimensional array-like object containing a sequence of values (of
# similar types to NumPy types) and an associated array of data labels, called its index.
# The simplest Series is formed from only an array of data:

# %%
import pandas as pd
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %% [markdown]
# The string representation of a Series displayed interactively shows the index on the
# left and the values on the right. Since we did not specify an index for the data, a
# default one consisting of the integers 0 through N - 1 (where N is the length of the
# data) is created.

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# We can create a Series with an index identifying each data point
# with a label

# %%
obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %% [markdown]
# you can use labels in the index when selecting single
# values or a set of values

# %%
print(obj2['a'])
obj2['d'] = 6
print(obj2[['c', 'a', 'd']])
# Out:
# -5
# c    3
# a   -5
# d    6
# dtype: int64

# %% [markdown]
# Using NumPy functions or NumPy-like operations, such as filtering with a boolean
# array, scalar multiplication, or applying math functions, will preserve the index-value

# %%
obj2[obj2 > 0]
obj2 * 2
# Out:
# d    12
# b    14
# a   -10
# c     6
# dtype: int64

# %% [markdown]
# Usage of in operator in series

# %%
'b' in obj2
'e' in obj2
# Out:
# False

# %% [markdown]
# Dictionary to Series:, you can create a Series from dict by
# passing the dict, When you are only passing a dict, the index in the resulting Series will have the dict’s
# keys in sorted order.

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %% [markdown]
# You can override this by passing the dict keys in the order you
# want them to appear in the resulting Series

# %%
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %% [markdown]
# since
# no value for 'California' was found, it appears as NaN (not a number), which is con‐
# sidered in pandas to mark missing or NA values. The
# isnull and notnull functions in pandas should be used to detect missing data.

# %%
pd.isnull(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
 pd.notnull(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %% [markdown]
# Concatenate two series

# %%
obj3 + obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %% [markdown]
# A Series’s index can be altered in-place by assignment:

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.index = ['Bob', 'Steve', 'Jeff', 'Ryan']
obj
# Out:
# Bob      4
# Steve    7
# Jeff    -5
# Ryan     3
# dtype: int64

# %% [markdown]
# DataFrame: A DataFrame represents a rectangular table of data and contains an ordered collection of columns, each of which can be a different value type (numeric, string,
# boolean, etc.). The DataFrame has both a row and column index; it can be thought of
# as a dict of Series all sharing the same index.

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada','Niveda'],
'year': [2000, 2001, 2002, 2001, 2002,2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9,3.2]}
frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Niveda  2003  3.2

# %% [markdown]
# If you specify a sequence of columns, the DataFrame’s columns will be arranged in
# that order:

# %%
# Can specify what to be added in columns
frame1=pd.DataFrame(data, columns=['year', 'state', 'pop'])
frame1
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Niveda  3.2

# %% [markdown]
# If you pass a column that isn’t contained in the dict, it will appear with missing values
# in the result

# %%
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],index=['one', 'two', 'three', 'four', 'five','six'])
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Niveda  3.2  NaN

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %% [markdown]
# A column in a DataFrame can be retrieved as a Series either by dict-like notation or
# by attribute:

# %%
frame2.year
frame2['state']
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2003
# Name: year, dtype: int64

# %% [markdown]
# Rows can also be retrieved by position or name with the special loc attribute

# %%
frame2.loc['three']
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: three, dtype: object

# %% [markdown]
# Columns can be modified by assignment. For example, the empty 'debt' column
# could be assigned a scalar value or an array of values

# %%
frame2['debt'] = 16.5
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5  16.5
# two    2001    Ohio  1.7  16.5
# three  2002    Ohio  3.6  16.5
# four   2001  Nevada  2.4  16.5
# five   2002  Nevada  2.9  16.5
# six    2003  Niveda  3.2  16.5

# %%
import numpy as np
frame2['debt'] = np.arange(6.)
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   0.0
# two    2001    Ohio  1.7   1.0
# three  2002    Ohio  3.6   2.0
# four   2001  Nevada  2.4   3.0
# five   2002  Nevada  2.9   4.0
# six    2003  Niveda  3.2   5.0

# %% [markdown]
# When you are assigning lists or arrays to a column, the value’s length must match the
# length of the DataFrame. If you assign a Series, its labels will be realigned exactly to
# the DataFrame’s index, inserting missing values in any holes

# %%
val = pd.Series([-1.2, -1.5, -1.7], index=['two', 'four', 'five'])
frame2['debt'] = val
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Niveda  3.2   NaN

# %% [markdown]
# Assigning a column that doesn’t exist will create a new column.

# %%
frame2['eastern'] = frame2.state == 'Ohio'
frame2
# Out:
#        year   state  pop  debt  eastern
# one    2000    Ohio  1.5   NaN     True
# two    2001    Ohio  1.7  -1.2     True
# three  2002    Ohio  3.6   NaN     True
# four   2001  Nevada  2.4  -1.5    False
# five   2002  Nevada  2.9  -1.7    False
# six    2003  Niveda  3.2   NaN    False

# %% [markdown]
# The del method can then be used to remove this column:

# %%
del frame2['eastern']
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Niveda  3.2   NaN

# %% [markdown]
# Nested Dicts:Another common form of data is a nested dict of dicts.

# %%
pop = {'Nevada': {2001: 2.4, 2002: 2.9},'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}
pop
# Out:
# {'Nevada': {2001: 2.4, 2002: 2.9}, 'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}

# %% [markdown]
# If the nested dict is passed to the DataFrame, pandas will interpret the outer dict keys
# as the columns and the inner keys as the row indices

# %%
frame3 = pd.DataFrame(pop)
frame3
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2000     NaN   1.5

# %% [markdown]
# You can transpose the DataFrame (swap rows and columns) with similar syntax to a
# NumPy array

# %%
frame3.T
# Out:
#         2001  2002  2000
# Nevada   2.4   2.9   NaN
# Ohio     1.7   3.6   1.5

# %% [markdown]
# Re-indexing: which means to create a new
# object with the data conformed to a new index.
